# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaeljane/100-days-of-code/blob/main/Roger_Ebert_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wptools in /usr/local/lib/python3.7/dist-packages (0.4.17)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from wptools) (4.2.6)
# Requirement already satisfied: pycurl in /usr/local/lib/python3.7/dist-packages (from wptools) (7.45.1)
# Requirement already satisfied: html2text in /usr/local/lib/python3.7/dist-packages (from wptools) (2020.1.16)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from wptools) (2022.5.18.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wptools in /usr/local/lib/python3.7/dist-packages (0.4.17)
# Requirement already satisfied: pycurl in /usr/local/lib/python3.7/dist-packages (from wptools) (7.45.1)
# Requirement already satisfied: html2text in /usr/local/lib/python3.7/dist-packages (from wptools) (2020.1.16)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from wptools) (4.2.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from wptools) (2022.5.18.1)

# %%
import wptools

# %%
page = wptools.page('E.T._the_Extra-Terrestrial').get()
# Out:
# en.wikipedia.org (query) E.T._the_Extra-Terrestrial
# en.wikipedia.org (query) E.T. the Extra-Terrestrial (&plcontinue=...
# en.wikipedia.org (parse) 73441
# www.wikidata.org (wikidata) Q11621
# www.wikidata.org (labels) P910|P6398|P5357|P5099|Q4834543|P4969|P...
# www.wikidata.org (labels) P2704|Q443775|P2508|Q21571487|P4786|Q25...
# www.wikidata.org (labels) Q34644|Q471839|P4529|Q506198|P244|Q3936...
# www.wikidata.org (labels) Q230390|Q816843|Q93605402|P6262|P3808|P...
# www.wikidata.org (labels) P9979|Q2143665|P2529|P3650|P161|P18|Q13...
# www.wikidata.org (labels) P3302
# en.wikipedia.org (restbase) /page/summary/E.T._the_Extra-Terrestrial
# en.wikipedia.org (imageinfo) File:E t the extra terrestrial ver3....
# E.T. the Extra-Terrestrial (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> E.T., ET
#   assessments: <dict(4)> United States, Film, Science Fiction, Lib...
#   claims: <dict(130)> P1562, P57, P272, P345, P31, P161, P373, P48...
#   description: 1982 American science fiction film
#   exhtml: <str(485)> <p><i><b>E.T. the Extra-Terrestrial</b></i> i...
#   exrest: <str(464)> E.T. the Extra-Terrestrial is a 1982 American...
#   extext: <str(2272)> _**E.T. the Extra-Terrestrial**_ (or simply ...
#   extract: <str(2398)> <p class="mw-empty-elt"></p><p><i><b>E.T. t...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:E t the e...
#   infobox: <dict(19)> name, image, alt, caption, director, produce...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:E...
#   label: E.T. the Extra-Terrestrial
#   labels: <dict(251)> P910, P6398, P5357, P5099, Q4834543, P4969, ...
#   length: 107,826
#   links: <list(641)> 12 Angry Men (1957 film), 12 Monkeys, 12 Year...
#   modified: <dict(2)> page, wikidata
#   pageid: 73441
#   parsetree: <str(132048)> <root><template><title>Redirect</title>...
#   random: Claudio Caligari
#   redirects: <list(37)> {'pageid': 177061, 'ns': 0, 'title': 'E.T....
#   requests: <list(12)> query, query, parse, wikidata, labels, labe...
#   title: E.T._the_Extra-Terrestrial
#   url: https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial
#   url_raw: <str(67)> https://en.wikipedia.org/wiki/E.T._the_Extra-...
#   watchers: 361
#   what: film
#   wikibase: Q11621
#   wikidata: <dict(130)> AllMovie title ID (P1562), director (P57),...
#   wikidata_pageid: 13150
#   wikidata_url: https://www.wikidata.org/wiki/Q11621
#   wikitext: <str(107448)> {{Redirect|E.T.|other uses|ET (disambigu...
# }
# en.wikipedia.org (query) E.T._the_Extra-Terrestrial
# en.wikipedia.org (query) E.T. the Extra-Terrestrial (&plcontinue=...
# en.wikipedia.org (parse) 73441
# www.wikidata.org (wikidata) Q11621
# www.wikidata.org (labels) P910|P6398|P5357|P5099|Q4834543|P4969|P...
# www.wikidata.org (labels) P2704|Q443775|P2508|Q21571487|P4786|Q25...
# www.wikidata.org (labels) Q34644|Q471839|P4529|Q506198|P244|Q3936...
# www.wikidata.org (labels) Q230390|Q816843|Q93605402|P6262|P3808|P...
# www.wikidata.org (labels) P9979|Q2143665|P2529|P3650|P161|P18|Q13...
# www.wikidata.org (labels) P3302
# en.wikipedia.org (restbase) /page/summary/E.T._the_Extra-Terrestrial
# en.wikipedia.org (imageinfo) File:E t the extra terrestrial ver3....
# E.T. the Extra-Terrestrial (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> E.T., ET
#   assessments: <dict(4)> United States, Film, Science Fiction, Lib...
#   claims: <dict(130)> P1562, P57, P272, P345, P31, P161, P373, P48...
#   description: 1982 American science fiction film
#   exhtml: <str(485)> <p><i><b>E.T. the Extra-Terrestrial</b></i> i...
#   exrest: <str(464)> E.T. the Extra-Terrestrial is a 1982 American...
#   extext: <str(2272)> _**E.T. the Extra-Terrestrial**_ (or simply ...
#   extract: <str(2398)> <p class="mw-empty-elt"></p><p><i><b>E.T. t...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:E t the e...
#   infobox: <dict(19)> name, image, alt, caption, director, produce...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:E...
#   label: E.T. the Extra-Terrestrial
#   labels: <dict(251)> P910, P6398, P5357, P5099, Q4834543, P4969, ...
#   length: 107,826
#   links: <list(641)> 12 Angry Men (1957 film), 12 Monkeys, 12 Year...
#   modified: <dict(2)> page, wikidata
#   pageid: 73441
#   parsetree: <str(132048)> <root><template><title>Redirect</title>...
#   random: Valley View, South Australia
#   redirects: <list(37)> {'pageid': 177061, 'ns': 0, 'title': 'E.T....
#   requests: <list(12)> query, query, parse, wikidata, labels, labe...
#   title: E.T._the_Extra-Terrestrial
#   url: https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial
#   url_raw: <str(67)> https://en.wikipedia.org/wiki/E.T._the_Extra-...
#   watchers: 361
#   what: film
#   wikibase: Q11621
#   wikidata: <dict(130)> AllMovie title ID (P1562), director (P57),...
#   wikidata_pageid: 13150
#   wikidata_url: https://www.wikidata.org/wiki/Q11621
#   wikitext: <str(107448)> {{Redirect|E.T.|other uses|ET (disambigu...
# }

# %%
page.data['image'][0]
# Out:
# {'descriptionshorturl': 'https://en.wikipedia.org/w/index.php?curid=7419503',
#  'descriptionurl': 'https://en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg',
#  'file': 'File:E t the extra terrestrial ver3.jpg',
#  'height': 394,
#  'kind': 'parse-image',
#  'metadata': {'Assessments': {'hidden': '',
#    'source': 'commons-categories',
#    'value': ''},
#   'Attribution': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<p>The poster art can or could be obtained from <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'Categories': {'hidden': '',
#    'source': 'commons-categories',
#    'value': 'All non-free media|E.T. the Extra-Terrestrial|Fair use images of film posters|Files with no machine-readable author|Noindexed pages|Wikipedia non-free files for NFUR review|Wikipedia non-free files with valid backlink'},
#   'CommonsMetadataExtension': {'hidden': '',
#    'source': 'extension',
#    'value': 1.2},
#   'Copyrighted': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': 'True'},
#   'Credit': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<p>The poster art can or could be obtained from <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'DateTime': {'hidden': '',
#    'source': 'mediawiki-metadata',
#    'value': '2016-06-04 10:30:46'},
#   'ImageDescription': {'source': 'commons-desc-page',
#    'value': '<p>This is a poster for  <i>E.T. the Extra-Terrestrial</i>. <br>The poster art copyright is believed to belong to <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'LicenseShortName': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': 'Fair use'},
#   'LicenseUrl': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '//en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg'},
#   'NonFree': {'hidden': '', 'source': 'commons-desc-page', 'value': 'true'},
#   'ObjectName': {'hidden': '',
#    'source': 'mediawiki-metadata',
#    'value': 'E t the extra terrestrial ver3'},
#   'Restrictions': {'hidden': '', 'source': 'commons-desc-page', 'value': ''},
#   'UsageTerms': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<a href="//en.wikipedia.org/wiki/Wikipedia:Non-free_use_rationale_guideline" title="Wikipedia:Non-free use rationale guideline">Fair use</a> of copyrighted material in the context of <a href="//en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial" title="E.T. the Extra-Terrestrial">E.T. the Extra-Terrestrial</a>'}},
#  'orig': 'E t the extra terrestrial ver3.jpg',
#  'size': 83073,
#  'timestamp': '2016-06-04T10:30:46Z',
#  'title': 'File:E t the extra terrestrial ver3.jpg',
#  'url': 'https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg',
#  'width': 253}
# {'descriptionshorturl': 'https://en.wikipedia.org/w/index.php?curid=7419503',
#  'descriptionurl': 'https://en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg',
#  'file': 'File:E t the extra terrestrial ver3.jpg',
#  'height': 394,
#  'kind': 'parse-image',
#  'metadata': {'Assessments': {'hidden': '',
#    'source': 'commons-categories',
#    'value': ''},
#   'Attribution': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<p>The poster art can or could be obtained from <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'Categories': {'hidden': '',
#    'source': 'commons-categories',
#    'value': 'All non-free media|E.T. the Extra-Terrestrial|Fair use images of film posters|Files with no machine-readable author|Noindexed pages|Wikipedia non-free files for NFUR review|Wikipedia non-free files with valid backlink'},
#   'CommonsMetadataExtension': {'hidden': '',
#    'source': 'extension',
#    'value': 1.2},
#   'Copyrighted': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': 'True'},
#   'Credit': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<p>The poster art can or could be obtained from <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'DateTime': {'hidden': '',
#    'source': 'mediawiki-metadata',
#    'value': '2016-06-04 10:30:46'},
#   'ImageDescription': {'source': 'commons-desc-page',
#    'value': '<p>This is a poster for  <i>E.T. the Extra-Terrestrial</i>. <br>The poster art copyright is believed to belong to <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>'},
#   'LicenseShortName': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': 'Fair use'},
#   'LicenseUrl': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '//en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg'},
#   'NonFree': {'hidden': '', 'source': 'commons-desc-page', 'value': 'true'},
#   'ObjectName': {'hidden': '',
#    'source': 'mediawiki-metadata',
#    'value': 'E t the extra terrestrial ver3'},
#   'Restrictions': {'hidden': '', 'source': 'commons-desc-page', 'value': ''},
#   'UsageTerms': {'hidden': '',
#    'source': 'commons-desc-page',
#    'value': '<a href="//en.wikipedia.org/wiki/Wikipedia:Non-free_use_rationale_guideline" title="Wikipedia:Non-free use rationale guideline">Fair use</a> of copyrighted material in the context of <a href="//en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial" title="E.T. the Extra-Terrestrial">E.T. the Extra-Terrestrial</a>'}},
#  'orig': 'E t the extra terrestrial ver3.jpg',
#  'size': 83073,
#  'timestamp': '2016-06-04T10:30:46Z',
#  'title': 'File:E t the extra terrestrial ver3.jpg',
#  'url': 'https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg',
#  'width': 253}

# %%
page.data['infobox']
# Out:
# {'alt': 'The poster shows the planet earth, a child\'s finger touching E.T\'s finger, with a light blinking on contact. The top headline reads "His Adventure On Earth".',
#  'budget': '$10.5 million',
#  'caption': 'Theatrical release poster by [[John Alvin]]',
#  'cinematography': '[[Allen Daviau]]',
#  'country': 'United States',
#  'director': '[[Steven Spielberg]]',
#  'distributor': '[[Universal Pictures]]',
#  'editing': '[[Carol Littleton]]',
#  'gross': '$792.9 million',
#  'image': 'E t the extra terrestrial ver3.jpg',
#  'language': 'English',
#  'music': '[[John Williams]]',
#  'name': 'E.T. the Extra-Terrestrial',
#  'producers': '{{unbulleted list|[[Kathleen Kennedy (producer)|Kathleen Kennedy]]|[[Steven Spielberg]]}}',
#  'released': '{{Film date|1982|5|26|[[1982 Cannes Film Festival|Cannes]]|1982|6|11|United States}}',
#  'runtime': '114 minutes (original) <br/>120 minutes (2002 version)',
#  'starring': '{{Plainlist|<!--Per poster billing-->|\n* [[Dee Wallace]]\n* [[Henry Thomas]]\n* [[Peter Coyote]]\n* [[Robert MacNaughton]]\n* [[Drew Barrymore]]}} * [[Dee Wallace]]\n* [[Henry Thomas]]\n* [[Peter Coyote]]\n* [[Robert MacNaughton]]\n* [[Drew Barrymore]]',
#  'studio': '[[Amblin Entertainment]]',
#  'writer': '[[Melissa Mathison]]'}
# {'alt': 'The poster shows the planet earth, a child\'s finger touching E.T\'s finger, with a light blinking on contact. The top headline reads "His Adventure On Earth".',
#  'budget': '$10.5 million',
#  'caption': 'Theatrical release poster by [[John Alvin]]',
#  'cinematography': '[[Allen Daviau]]',
#  'country': 'United States',
#  'director': '[[Steven Spielberg]]',
#  'distributor': '[[Universal Pictures]]',
#  'editing': '[[Carol Littleton]]',
#  'gross': '$792.9 million',
#  'image': 'E t the extra terrestrial ver3.jpg',
#  'language': 'English',
#  'music': '[[John Williams]]',
#  'name': 'E.T. the Extra-Terrestrial',
#  'producers': '{{unbulleted list|[[Kathleen Kennedy (producer)|Kathleen Kennedy]]|[[Steven Spielberg]]}}',
#  'released': '{{Film date|1982|5|26|[[1982 Cannes Film Festival|Cannes]]|1982|6|11|United States}}',
#  'runtime': '114 minutes (original) <br/>120 minutes (2002 version)',
#  'starring': '{{Plainlist|<!--Per poster billing-->|\n* [[Dee Wallace]]\n* [[Henry Thomas]]\n* [[Peter Coyote]]\n* [[Robert MacNaughton]]\n* [[Drew Barrymore]]}} * [[Dee Wallace]]\n* [[Henry Thomas]]\n* [[Peter Coyote]]\n* [[Robert MacNaughton]]\n* [[Drew Barrymore]]',
#  'studio': '[[Amblin Entertainment]]',
#  'writer': '[[Melissa Mathison]]'}

# %%
page.data['infobox']['director']
# Out:
# '[[Steven Spielberg]]'
# '[[Steven Spielberg]]'

# %%
import pandas as pd
import wptools
import os
import requests
from PIL import Image
from io import BytesIO

# %%
title_list = [
 'The_Wizard_of_Oz_(1939_film)',
 'Citizen_Kane',
 'The_Third_Man',
 'Get_Out_(film)',
 'Mad_Max:_Fury_Road',
 'The_Cabinet_of_Dr._Caligari',
 'All_About_Eve',
 'Inside_Out_(2015_film)',
 'The_Godfather',
 'Metropolis_(1927_film)',
 'E.T._the_Extra-Terrestrial',
 'Modern_Times_(film)',
 'It_Happened_One_Night',
 "Singin'_in_the_Rain",
 'Boyhood_(film)',
 'Casablanca_(film)',
 'Moonlight_(2016_film)',
 'Psycho_(1960_film)',
 'Laura_(1944_film)',
 'Nosferatu',
 'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
 "A_Hard_Day%27s_Night_(film)",
 'La_Grande_Illusion',
 'North_by_Northwest',
 'The_Battle_of_Algiers',
 'Dunkirk_(2017_film)',
 'The_Maltese_Falcon_(1941_film)',
 'Repulsion_(film)',
 '12_Years_a_Slave_(film)',
 'Gravity_(2013_film)',
 'Sunset_Boulevard_(film)',
 'King_Kong_(1933_film)',
 'Spotlight_(film)',
 'The_Adventures_of_Robin_Hood',
 'Rashomon',
 'Rear_Window',
 'Selma_(film)',
 'Taxi_Driver',
 'Toy_Story_3',
 'Argo_(2012_film)',
 'Toy_Story_2',
 'The_Big_Sick',
 'Bride_of_Frankenstein',
 'Zootopia',
 'M_(1931_film)',
 'Wonder_Woman_(2017_film)',
 'The_Philadelphia_Story_(film)',
 'Alien_(film)',
 'Bicycle_Thieves',
 'Seven_Samurai',
 'The_Treasure_of_the_Sierra_Madre_(film)',
 'Up_(2009_film)',
 '12_Angry_Men_(1957_film)',
 'The_400_Blows',
 'Logan_(film)',
 'All_Quiet_on_the_Western_Front_(1930_film)',
 'Army_of_Shadows',
 'Arrival_(film)',
 'Baby_Driver',
 'A_Streetcar_Named_Desire_(1951_film)',
 'The_Night_of_the_Hunter_(film)',
 'Star_Wars:_The_Force_Awakens',
 'Manchester_by_the_Sea_(film)',
 'Dr._Strangelove',
 'Frankenstein_(1931_film)',
 'Vertigo_(film)',
 'The_Dark_Knight_(film)',
 'Touch_of_Evil',
 'The_Babadook',
 'The_Conformist_(film)',
 'Rebecca_(1940_film)',
 "Rosemary%27s_Baby_(film)",
 'Finding_Nemo',
 'Brooklyn_(film)',
 'The_Wrestler_(2008_film)',
 'The_39_Steps_(1935_film)',
 'L.A._Confidential_(film)',
 'Gone_with_the_Wind_(film)',
 'The_Good,_the_Bad_and_the_Ugly',
 'Skyfall',
 'Rome,_Open_City',
 'Tokyo_Story',
 'Hell_or_High_Water_(film)',
 'Pinocchio_(1940_film)',
 'The_Jungle_Book_(2016_film)',
 'La_La_Land_(film)',
 'Star_Trek_(film)',
 'High_Noon',
 'Apocalypse_Now',
 'On_the_Waterfront',
 'The_Wages_of_Fear',
 'The_Last_Picture_Show',
 'Harry_Potter_and_the_Deathly_Hallows_–_Part_2',
 'The_Grapes_of_Wrath_(film)',
 'Roman_Holiday',
 'Man_on_Wire',
 'Jaws_(film)',
 'Toy_Story',
 'The_Godfather_Part_II',
 'Battleship_Potemkin'
]

# %%
movies = 'bestofrt_posters'
# Make directory 
if not os.path.exists(movies):
    os.makedirs(movies)

# %%
#make empty list
# List of dictionaries to build and convert to a DataFrame later
df_list = []
image_errors = {}
for title in title_list:
    try:
        # This cell is slow so print ranking to gauge time remaining
        ranking = title_list.index(title) + 1
        print(ranking)
        page = wptools.page(title, silent=True)
        # Your code here (three lines)
        images = page.get().data['image']
        # First image is usually the poster
        first_image_url = images[0]['url']
        r = requests.get(first_image_url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = first_image_url.split('.')[-1]
        i.save(movies + "/" + str(ranking) + "_" + title + '.' + image_file_format)
        # Append to list of dictionaries
        df_list.append({'ranking': int(ranking),
                        'title': title,
                        'poster_url': first_image_url})
    
    # Not best practice to catch all exceptions but fine for this short script
    except Exception as e:
        print(str(ranking) + "_" + title + ": " + str(e))
        image_errors[str(ranking) + "_" + title] = images
# Out:
# 1
# 2
# 3
# 3_The_Third_Man: cannot identify image file <_io.BytesIO object at 0x7f6a86a67e30>
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 10_Metropolis_(1927_film): cannot identify image file <_io.BytesIO object at 0x7f6a85798fb0>
# 11
# 12
# 13
# 14
# 14_Singin'_in_the_Rain: cannot identify image file <_io.BytesIO object at 0x7f6a85778fb0>
# 15
# 15_Boyhood_(film): 'image'
# 16
# 17
# 18
# 18_Psycho_(1960_film): cannot identify image file <_io.BytesIO object at 0x7f6a8580ecb0>
# 19
# 19_Laura_(1944_film): cannot identify image file <_io.BytesIO object at 0x7f6a86235230>
# 20
# 21
# 22
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 22_A_Hard_Day%27s_Night_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=A_Hard_Day%2527s_Night_%28film%29
# 23
# 24
# 25
# 25_The_Battle_of_Algiers: cannot identify image file <_io.BytesIO object at 0x7f6a860e8950>
# 26
# 27
# 27_The_Maltese_Falcon_(1941_film): cannot identify image file <_io.BytesIO object at 0x7f6a860f6710>
# 28
# 29
# 30
# 31
# 32
# 33
# 33_Spotlight_(film): https://en.wikipedia.org/w/api.php?action=query&exintro&formatversion=2&inprop=url|watchers&list=random&pithumbsize=240&pllimit=500&ppprop=disambiguation|wikibase_item&prop=extracts|info|links|pageassessments|pageimages|pageprops|pageterms|redirects&redirects&rdlimit=500&rnlimit=1&rnnamespace=0&titles=Spotlight%20%28film%29&plcontinue=43842546|0|Satellite_Award_for_Best_Supporting_Actress_–_Motion_Picture
# 34
# 35
# 36
# 36_Rear_Window: cannot identify image file <_io.BytesIO object at 0x7f6a8611b1d0>
# 37
# 38
# 39
# 40
# 40_Argo_(2012_film): https://en.wikipedia.org/w/api.php?action=query&exintro&formatversion=2&inprop=url|watchers&list=random&pithumbsize=240&pllimit=500&ppprop=disambiguation|wikibase_item&prop=extracts|info|links|pageassessments|pageimages|pageprops|pageterms|redirects&redirects&rdlimit=500&rnlimit=1&rnnamespace=0&titles=Argo%20%282012%20film%29&plcontinue=33028800|0|Uganda–Tanzania_War
# 41
# 42
# 43
# 43_Bride_of_Frankenstein: cannot identify image file <_io.BytesIO object at 0x7f6a8576ad10>
# 44
# 45
# 45_M_(1931_film): cannot identify image file <_io.BytesIO object at 0x7f6a86179fb0>
# 46
# 47
# 47_The_Philadelphia_Story_(film): cannot identify image file <_io.BytesIO object at 0x7f6a85819050>
# 48
# 49
# 50
# 51
# 51_The_Treasure_of_the_Sierra_Madre_(film): cannot identify image file <_io.BytesIO object at 0x7f6a861e7ad0>
# 52
# 53
# 54
# 55
# 56
# 56_All_Quiet_on_the_Western_Front_(1930_film): cannot identify image file <_io.BytesIO object at 0x7f6a861d8770>
# 57
# 58
# 58_Arrival_(film): cannot identify image file <_io.BytesIO object at 0x7f6a857967d0>
# 59
# 60
# 60_A_Streetcar_Named_Desire_(1951_film): cannot identify image file <_io.BytesIO object at 0x7f6a8618ecb0>
# 61
# 61_The_Night_of_the_Hunter_(film): cannot identify image file <_io.BytesIO object at 0x7f6a8580e170>
# 62
# 63
# 64
# 65
# 66
# 66_Vertigo_(film): cannot identify image file <_io.BytesIO object at 0x7f6a860f5290>
# 67
# 68
# 68_Touch_of_Evil: cannot identify image file <_io.BytesIO object at 0x7f6a860f5290>
# 69
# 70
# 71
# 71_Rebecca_(1940_film): cannot identify image file <_io.BytesIO object at 0x7f6a86116ef0>
# 72
# API error: {'code': 'invalidtitle', 'info': 'Bad title "Rosemary%27s_Baby_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 72_Rosemary%27s_Baby_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=Rosemary%2527s_Baby_%28film%29
# 73
# 74
# 75
# 76
# 76_The_39_Steps_(1935_film): cannot identify image file <_io.BytesIO object at 0x7f6a8614ca70>
# 77
# 78
# 78_Gone_with_the_Wind_(film): cannot identify image file <_io.BytesIO object at 0x7f6a857434d0>
# 79
# 80
# 81
# 82
# 82_Tokyo_Story: cannot identify image file <_io.BytesIO object at 0x7f6a857c85f0>
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 90_On_the_Waterfront: cannot identify image file <_io.BytesIO object at 0x7f6a860e8a70>
# 91
# 92
# 93
# 94
# 94_The_Grapes_of_Wrath_(film): cannot identify image file <_io.BytesIO object at 0x7f6a85738350>
# 95
# 95_Roman_Holiday: cannot identify image file <_io.BytesIO object at 0x7f6a8580ea70>
# 96
# 97
# 98
# 99
# 100
# 100_Battleship_Potemkin: cannot identify image file <_io.BytesIO object at 0x7f6a85738950>
# 1
# 2
# 3
# 3_The_Third_Man: cannot identify image file <_io.BytesIO object at 0x7f6a85738e90>
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 10_Metropolis_(1927_film): cannot identify image file <_io.BytesIO object at 0x7f6a86235230>
# 11
# 12
# 13
# 14
# 14_Singin'_in_the_Rain: cannot identify image file <_io.BytesIO object at 0x7f6a861ee350>
# 15
# 15_Boyhood_(film): 'image'
# 16
# 17
# 18
# 18_Psycho_(1960_film): cannot identify image file <_io.BytesIO object at 0x7f6a8620ffb0>
# 19
# 19_Laura_(1944_film): cannot identify image file <_io.BytesIO object at 0x7f6a861ee350>
# 20
# 21
# 22
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 22_A_Hard_Day%27s_Night_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=A_Hard_Day%2527s_Night_%28film%29
# 23
# 24
# 25
# 25_The_Battle_of_Algiers: cannot identify image file <_io.BytesIO object at 0x7f6a861492f0>
# 26
# 27
# 27_The_Maltese_Falcon_(1941_film): cannot identify image file <_io.BytesIO object at 0x7f6a8d5cf110>
# 28
# 29
# 30
# 31
# 32
# 33
# 33_Spotlight_(film): https://en.wikipedia.org/w/api.php?action=query&exintro&formatversion=2&inprop=url|watchers&list=random&pithumbsize=240&pllimit=500&ppprop=disambiguation|wikibase_item&prop=extracts|info|links|pageassessments|pageimages|pageprops|pageterms|redirects&redirects&rdlimit=500&rnlimit=1&rnnamespace=0&titles=Spotlight%20%28film%29&plcontinue=43842546|0|Satellite_Award_for_Best_Supporting_Actress_–_Motion_Picture
# 34
# 35
# 36
# 36_Rear_Window: cannot identify image file <_io.BytesIO object at 0x7f6a861e7bf0>
# 37
# 38
# 39
# 40
# 40_Argo_(2012_film): https://en.wikipedia.org/w/api.php?action=query&exintro&formatversion=2&inprop=url|watchers&list=random&pithumbsize=240&pllimit=500&ppprop=disambiguation|wikibase_item&prop=extracts|info|links|pageassessments|pageimages|pageprops|pageterms|redirects&redirects&rdlimit=500&rnlimit=1&rnnamespace=0&titles=Argo%20%282012%20film%29&plcontinue=33028800|0|Uganda–Tanzania_War
# 41
# 42
# 43
# 43_Bride_of_Frankenstein: cannot identify image file <_io.BytesIO object at 0x7f6a857e4410>
# 44
# 45
# 45_M_(1931_film): cannot identify image file <_io.BytesIO object at 0x7f6a857cdf50>
# 46
# 47
# 47_The_Philadelphia_Story_(film): cannot identify image file <_io.BytesIO object at 0x7f6a860ecb90>
# 48
# 49
# 50
# 51
# 51_The_Treasure_of_the_Sierra_Madre_(film): cannot identify image file <_io.BytesIO object at 0x7f6a8614ce30>
# 52
# 53
# 54
# 55
# 56
# 56_All_Quiet_on_the_Western_Front_(1930_film): cannot identify image file <_io.BytesIO object at 0x7f6a856462f0>
# 57
# 58
# 59
# 60
# 60_A_Streetcar_Named_Desire_(1951_film): cannot identify image file <_io.BytesIO object at 0x7f6a857db530>
# 61
# 61_The_Night_of_the_Hunter_(film): cannot identify image file <_io.BytesIO object at 0x7f6a86235230>
# 62
# 63
# 64
# 65
# 66
# 66_Vertigo_(film): cannot identify image file <_io.BytesIO object at 0x7f6a85625b30>
# 67
# 68
# 68_Touch_of_Evil: cannot identify image file <_io.BytesIO object at 0x7f6a85764230>
# 69
# 70
# 71
# 71_Rebecca_(1940_film): cannot identify image file <_io.BytesIO object at 0x7f6a860e8a70>
# 72
# API error: {'code': 'invalidtitle', 'info': 'Bad title "Rosemary%27s_Baby_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 72_Rosemary%27s_Baby_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=Rosemary%2527s_Baby_%28film%29
# 73
# 74
# 75
# 76
# 76_The_39_Steps_(1935_film): cannot identify image file <_io.BytesIO object at 0x7f6a8618ea70>
# 77
# 78
# 78_Gone_with_the_Wind_(film): cannot identify image file <_io.BytesIO object at 0x7f6a85762590>
# 79
# 80
# 81
# 82
# 82_Tokyo_Story: cannot identify image file <_io.BytesIO object at 0x7f6a86104650>
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 90_On_the_Waterfront: cannot identify image file <_io.BytesIO object at 0x7f6a857cdad0>
# 91
# 92
# 93
# 94
# 94_The_Grapes_of_Wrath_(film): cannot identify image file <_io.BytesIO object at 0x7f6a858011d0>
# 95
# 95_Roman_Holiday: cannot identify image file <_io.BytesIO object at 0x7f6a86116e90>
# 96
# 97
# 98
# 99
# 100
# 100_Battleship_Potemkin: cannot identify image file <_io.BytesIO object at 0x7f6a8611ba10>

# %%
for key in image_errors.keys():
    print(key)
# Out:
# 3_The_Third_Man
# 10_Metropolis_(1927_film)
# 14_Singin'_in_the_Rain
# 15_Boyhood_(film)
# 18_Psycho_(1960_film)
# 19_Laura_(1944_film)
# 22_A_Hard_Day%27s_Night_(film)
# 25_The_Battle_of_Algiers
# 27_The_Maltese_Falcon_(1941_film)
# 33_Spotlight_(film)
# 36_Rear_Window
# 40_Argo_(2012_film)
# 43_Bride_of_Frankenstein
# 45_M_(1931_film)
# 47_The_Philadelphia_Story_(film)
# 51_The_Treasure_of_the_Sierra_Madre_(film)
# 56_All_Quiet_on_the_Western_Front_(1930_film)
# 60_A_Streetcar_Named_Desire_(1951_film)
# 61_The_Night_of_the_Hunter_(film)
# 66_Vertigo_(film)
# 68_Touch_of_Evil
# 71_Rebecca_(1940_film)
# 72_Rosemary%27s_Baby_(film)
# 76_The_39_Steps_(1935_film)
# 78_Gone_with_the_Wind_(film)
# 82_Tokyo_Story
# 90_On_the_Waterfront
# 94_The_Grapes_of_Wrath_(film)
# 95_Roman_Holiday
# 100_Battleship_Potemkin

# %%
# Inspect unidentifiable images and download them individually
for rank_title, images in image_errors.items():
    if rank_title == '22_A_Hard_Day%27s_Night_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/4/47/A_Hard_Days_night_movieposter.jpg'
    if rank_title == '53_12_Angry_Men_(1957_film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg'
    if rank_title == '72_Rosemary%27s_Baby_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/e/ef/Rosemarys_baby_poster.jpg'
    if rank_title == '93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2':
        url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
    title = rank_title[3:]
    df_list.append({'ranking': int(title_list.index(title) + 1),
                    'title': title,
                    'poster_url': url})
    r = requests.get(url)
    # Download movie poster image
    i = Image.open(BytesIO(r.content))
    image_file_format = url.split('.')[-1]
    i.save(folder_name + "/" + rank_title + '.' + image_file_format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-21400a637b79> in <module>()
#      10         url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
#      11     title = rank_title[3:]
# ---> 12     df_list.append({'ranking': int(title_list.index(title) + 1),
#      13                     'title': title,
#      14                     'poster_url': url})
#
# ValueError: 'he_Third_Man' is not in list

# %%
# Create DataFrame from list of dictionaries
df = pd.DataFrame(df_list, columns = ['ranking', 'title', 'poster_url'])
df = df.sort_values('ranking').reset_index(drop=True)
df
# Out:
#     ranking                                          title  \
# 0         1                   The_Wizard_of_Oz_(1939_film)
# 1         2                                   Citizen_Kane
# 2         4                                 Get_Out_(film)
# 3         5                             Mad_Max:_Fury_Road
# 4         6                    The_Cabinet_of_Dr._Caligari
# ..      ...                                            ...
# 65       93  Harry_Potter_and_the_Deathly_Hallows_–_Part_2
# 66       96                                    Man_on_Wire
# 67       97                                    Jaws_(film)
# 68       98                                      Toy_Story
# 69       99                          The_Godfather_Part_II
#
#                                            poster_url
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/commons...
# 2   https://upload.wikimedia.org/wikipedia/en/a/a3...
# 3   https://upload.wikimedia.org/wikipedia/en/6/6e...
# 4   https://upload.wikimedia.org/wikipedia/en/2/2f...
# ..                                                ...
# 65  https://upload.wikimedia.org/wikipedia/en/d/df...
# 66  https://upload.wikimedia.org/wikipedia/en/5/54...
# 67  https://upload.wikimedia.org/wikipedia/en/e/eb...
# 68  https://upload.wikimedia.org/wikipedia/en/1/13...
# 69  https://upload.wikimedia.org/wikipedia/en/0/03...
#
# [70 rows x 3 columns]
