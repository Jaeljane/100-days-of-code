# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaeljane/100-days-of-code/blob/main/Importing_data_from_google_sheets_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  --upgrade gspread
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import auth
auth.authenticate_user()
import pandas as pd
import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

wb = gc.open_by_key('1KUkiVbJzaUIWX9bVsC91-tpOAoWqLE7tVQjiOZWSHsM')
ws=wb.worksheet('Supplier Invoice Statement')

# get_all_values gives a list of rows.
rows = ws.get_all_values()

# Convert to a DataFrame and render.

df=pd.DataFrame.from_records(rows[1:], columns=rows[0])
df.head()
# Out:
#   Document No Payment No.    Paid Invoiced Inv/cr Paid Amount  \
# 0       24673           1  Apr 17   Mar 23   INV
#     S 742.50
# 1       24673           1  Apr 20   Apr 01   inv
#    S 1021.02
# 2       24675           1  Apr 05   Mar 16   INV
#     S 409.53
# 3       24676           1  Apr 20   Mar 25   cr
#     S 234.96
# 4       24677           1  Apr 10   Mar 17    cr
#     S 450.12
#
#            Customer PO   ABN     Acct Check Payment No     Bank Details  \
# 0     PO-Sydney-223809  1641  7654320    72    24673_1  1641-7654320-72
# 1  PO-Melbourne-327600  2554  4551221    33    24673_1  2554-4551221-33
# 2  PO-Melbourne-332589  2554  4551221    33    24675_1  2554-4551221-33
# 3  PO-Melbourne-337131  2554  4551221    33    24676_1  2554-4551221-33
# 4  PO-Melbourne-319376  2554  4551221    33    24677_1  2554-4551221-33
#
#   Inv Month PO Number Location Type $ Amount
# 0       Mar    223809        S
# 1       Apr    327600        M
# 2       Mar    332589        M
# ...

# %% [markdown]
# ##Alternative method

# %%
df = pd.DataFrame(rows)
df.columns = df.iloc[0]
df = df.iloc[1:]
df.head()
# Out:
# 0 Document No Payment No.    Paid Invoiced Inv/cr Paid Amount  \
# 1       24673           1  Apr 17   Mar 23   INV
#     S 742.50
# 2       24673           1  Apr 20   Apr 01   inv
#    S 1021.02
# 3       24675           1  Apr 05   Mar 16   INV
#     S 409.53
# 4       24676           1  Apr 20   Mar 25   cr
#     S 234.96
# 5       24677           1  Apr 10   Mar 17    cr
#     S 450.12
#
# 0          Customer PO   ABN     Acct Check Payment No     Bank Details  \
# 1     PO-Sydney-223809  1641  7654320    72    24673_1  1641-7654320-72
# 2  PO-Melbourne-327600  2554  4551221    33    24673_1  2554-4551221-33
# 3  PO-Melbourne-332589  2554  4551221    33    24675_1  2554-4551221-33
# 4  PO-Melbourne-337131  2554  4551221    33    24676_1  2554-4551221-33
# 5  PO-Melbourne-319376  2554  4551221    33    24677_1  2554-4551221-33
#
# 0 Inv Month PO Number Location Type $ Amount
# 1       Mar    223809        S
# 2       Apr    327600        M
# 3       Mar    332589        M
# ...

# %%
df.shape
# Out:
# (84, 17)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Second workbook

# %%
ws2=wb.worksheet('MC Invoice Report')

# get_all_values gives a list of rows.
rows2 = ws2.get_all_values()

# Convert to a DataFrame and render.

df2=pd.DataFrame.from_records(rows2[1:], columns=rows2[0])
df2.head()
# Out:
#   Payment Ref Supplier Code Payment No. Invoice Date   Due Date Payment Date  \
# 0     24673_1        MC2741      545671    27/3/2010  27/4/2010     1/4/2010
# 1     24673_1        MC2741      545672     3/3/2010   5/4/2010     2/4/2010
# 2     24675_1        MC2741      545674    19/2/2010  19/3/2010     3/4/2010
# 3     24676_1        MC2741      545676    11/3/2010  12/4/2010     3/4/2010
# 4     24677_1        MC2741      545677    21/3/2010  21/4/2010     4/4/2010
#
#       Bank Details PO Number   Location     Amount Invoice Month Over Due By  \
# 0  1641-7654320-72    223809     Sydney    $742.50
# 1  2554-4551221-33    327600  Melbourne  $1,021.02
# 2  2554-4551221-33    332589  Melbourne    $409.53
# 3  2554-4551221-33    337131  Melbourne   -$234.96
# 4  2554-4551221-33    319376  Melbourne   -$450.12
#
#   Late Charge
# 0
# 1
# 2
# 3
# 4

# %%
df2.shape
# Out:
# (84, 13)
